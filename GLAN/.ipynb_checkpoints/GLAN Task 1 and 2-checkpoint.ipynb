# %%
import pandas as pd

# Load the Excel file
xl = pd.ExcelFile("LME Approved Brands (2).xlsx")

# Get the sheet names
sheet_names = xl.sheet_names
sheet_names
# Out:
# ['Copper - Grade A',
#  'Lead',
#  'Special High Grade Zinc',
#  'Tin',
#  'Primary Nickel',
#  'High Grade Primary Aluminium',
#  'Aluminium Alloy',
#  'NASAAC',
#  'Cobalt']

# %%
# A dictionary to hold the dataframes
dataframes = {}

# Loop over the sheet names, loading and cleaning each one
for sheet_name in sheet_names:
    df = pd.read_excel("LME Approved Brands (2).xlsx", sheet_name=sheet_name, skiprows=5)
    dataframes[sheet_name] = df

# Display a sample from each dataframe
dataframe_samples = {sheet_name: df.head() for sheet_name, df in dataframes.items()}
dataframe_samples
# Out:
# {'Copper - Grade A':    Country/Region  Brand LMEsword Code   \
#  0       Australia    ISA            ISA
#  1       Australia  OLYDA          OLYDA
#  2         Austria    BRX            BRX
#  3         Belgium   OLEN           OLEN
#  4          Brazil    CbM            CBM
#
#                                    Producer    Deliverable Shape  \
#  0                      Mount Isa Mines Ltd  Full plate cathodes
#  1      BHP Olympic Dam Corporation Pty Ltd  Full plate cathodes
#  2  Montanwerke Brixlegg Aktiengesellschaft  Full plate cathodes
#  3                Aurubis Belgium n.v./s.a.  Full plate cathodes
#  4                        Paranapanema S.A.  Full plate cathodes
#
#    Warrant Issuance Last Warrantable Date Special Notes
#  0      WARRANTABLE                   NaT           NaN
#  1      WARRANTABLE                   NaT           NaN
#  2      WARRANTABLE                   NaT           NaN
#  3      WARRANTABLE                   NaT           NaN
#  4      WARRANTABLE                   NaT           NaN  ,
#  'Lead':    Country/Region                                      Brand LMEsword Code  \
#  0       Australia                          NYRSTAR BHAS 9997        NYRS97
#  1       Australia                          NYRSTAR BHAS 9999        NYRS99
#  2       Australia  ZINIFEX BHAS BROKEN HILL - AUSTRALIA 9997        ZIN997
#  3         Austria                                        BBU           BBU
#  4         Belgium                        MCR MADE IN BELGIUM        MCRBEL
#
#                         Producer Deliverable Shape  \
#  0  Nyrstar Sales & Marketing AG            Ingots
#  1  Nyrstar Sales & Marketing AG            Ingots
#  2  Nyrstar Sales & Marketing AG            Ingots
#  3      ECOBAT Resources Austria            Ingots
#  4          Campine Recycling NV            Ingots
#
#                  Warrant Issuance Last Warrantable Date Special Notes  \
#  0                    WARRANTABLE                   NaT           NaN
#  1                    WARRANTABLE                   NaT           NaN
#  2  NO NEW WARRANTS CAN BE ISSUED                   NaT           NaN
#  3                    WARRANTABLE                   NaT           NaN
#  4                    WARRANTABLE                   NaT           NaN
#
#     Unnamed: 8 GRADES  99.97 99.985 99.99 99.97.1 99.985.1 99.99.1 99.994  \
#  0         NaN     NaN     Y    NaN   NaN     NaN      NaN     NaN    NaN
#  1         NaN     NaN   NaN    NaN     Y     NaN      NaN     NaN    NaN
#  2         NaN     NaN     Y    NaN   NaN       Y      NaN     NaN    NaN
#  3         NaN     NaN     Y    NaN   NaN     NaN      NaN     NaN    NaN
#  4         NaN     NaN     Y    NaN   NaN     NaN      NaN     NaN    NaN
#
#    99.97.2 99.995
#  0     NaN    NaN
#  1     NaN    NaN
#  2     NaN    NaN
#  3     NaN    NaN
#  4     NaN    NaN  ,
#  'Special High Grade Zinc':    Country/Region                   Brand LMEsword Code  \
#  0       Australia          NYRSTAR A-Z Z1         NYRAZ
#  1       Australia          SMC SHG 99.995        SMCSHG
#  2         Belgium     NYRSTAR OVERPELT Z1        NYROVC
#  3          Brazil  VOTORANTIM JF ZINC SHG        VOTOJF
#  4          Brazil  VOTORANTIM TM ZINC SHG        VOTOTM
#
#                           Producer Deliverable Shape Warrant Issuance  \
#  0    Nyrstar Sales & Marketing AG            Ingots      WARRANTABLE
#  1  Sun Metals Corporation Pty Ltd            Ingots      WARRANTABLE
#  2    Nyrstar Sales & Marketing AG            Ingots      WARRANTABLE
#  3     Nexa Recursos Minerais S.A.            Ingots      WARRANTABLE
#  4     Nexa Recursos Minerais S.A.            Ingots      WARRANTABLE
#
#     Last Warrantable Date Special Notes
#  0                    NaN           NaN
#  1                    NaN           NaN
#  2                    NaN           NaN
#  3                    NaN           NaN
#  4                    NaN           NaN  ,
#  'Tin':    Country/Region            Brand LMEsword Code  \
#  0         Belgium                M           MSN
#  1         Bolivia             ENAF          ENAF
#  2          Brazil           MAMORE        MAMORE
#  3          Brazil  WHITE SOLDER BR        WTSOBR
#  4           China               JH            JH
#
#                                     Producer Deliverable Shape  \
#  0                         Aurubis Beerse NV            Ingots
#  1                 Empresa Metalurgica Vinto            Ingots
#  2                       Mineracao Taboca SA            Ingots
#  3  White Solder Metalurgia e Mineracao LTDA            Ingots
#  4                China Tin Smelter Co. Ltd.            Ingots
#
#    Warrant Issuance  Last Warrantable Date Special Notes
#  0      WARRANTABLE                    NaN           NaN
#  1      WARRANTABLE                    NaN           NaN
#  2      WARRANTABLE                    NaN           NaN
#  3      WARRANTABLE                    NaN           NaN
#  4      WARRANTABLE                    NaN           NaN  ,
#  'Primary Nickel':    Country/Region                                Brand LMEsword Code  \
#  0       Australia       BHP BILLITON NICKEL BRIQUETTES           BHP
#  1       Australia                BHP NICKEL BRIQUETTES         BHPNB
#  2       Australia  MINARA HIGH GRADE NICKEL BRIQUETTES        MINARA
#  3          Brazil                            TOCANTINS        TOCANT
#  4          Canada           SHERRITT NICKEL BRIQUETTES        SHERRI
#
#                             Producer                 Deliverable Shape  \
#  0  BHP Billiton Nickel West Pty Ltd      Briquettes,Bagged briquettes
#  1           BHP Nickel West Pty Ltd                 Bagged briquettes
#  2          Minara Resources Pty Ltd      Briquettes,Bagged briquettes
#  3            Votorantim Metais S.A.  Cut cathodes,Full plate cathodes
#  4   The Cobalt Refinery Company Inc      Briquettes,Bagged briquettes
#
#                                      Warrant Issuance Last Warrantable Date  \
#  0  NEW WARRANTS CANNOT BE ISSUED FROM THE DEFINED...            2022-11-23
#  1                                        WARRANTABLE                   NaT
#  2                                        WARRANTABLE                   NaT
#  3                      NO NEW WARRANTS CAN BE ISSUED                   NaT
#  4                                        WARRANTABLE                   NaT
#
#     Special Notes
#  0            NaN
#  1            NaN
#  2            NaN
#  3            NaN
#  4            NaN  ,
#  'High Grade Primary Aluminium':    Country/Region     Brand LMEsword Code  \
#  0       Argentina     ALUAR         ALUAR
#  1       Australia       BBY           BBY
#  2       Australia       BSL           BSL
#  3       Australia  PORTLAND        PORTLA
#  4       Australia    TOMAGO        TOMAGO
#
#                                   Producer Deliverable Shape Warrant Issuance  \
#  0           Aluar Aluminio Argentino SAIC     Ingots,T-bars      WARRANTABLE
#  1  Rio Tinto Aluminium (Bell Bay) Limited     Ingots,T-bars      WARRANTABLE
#  2                      Boyne Smelters Ltd     Ingots,T-bars      WARRANTABLE
#  3        Alcoa Portland Aluminium Pty Ltd            Ingots      WARRANTABLE
#  4             Tomago Aluminium Co Pty Ltd     Ingots,T-bars      WARRANTABLE
#
#     Last Warrantable Date Special Notes
#  0                    NaN           NaN
#  1                    NaN           NaN
#  2                    NaN           NaN
#  3                    NaN           NaN
#  4                    NaN           NaN  ,
#  'Aluminium Alloy':    Country/Region      Brand LMEsword Code   \
#  0       Australia   PORTLAND         PORTAA
#  1       Australia     TOMAGO         TOMGAA
#  2          Canada   WABASH M            WAM
#  3           China  YECHIU TC           YETC
#  4           China        ZSM            ZSM
#
#                                 Producer  Deliverable Shape  \
#  0      Alcoa Portland Aluminium Pty Ltd             Ingots
#  1           Tomago Aluminium Co Pty Ltd             Ingots
#  2                Real Alloy Canada Ltd.  Ingots,Small sows
#  3  Ye Chiu Metal Recycling (China) Ltd.             Ingots
#  4           Zhangzhou Sigma Metals Inc.             Ingots
#
#                  Warrant Issuance  Last Warrantable Date Special Notes
#  0                    WARRANTABLE                    NaN           NaN
#  1                    WARRANTABLE                    NaN           NaN
#  2                    WARRANTABLE                    NaN           NaN
#  3                    WARRANTABLE                    NaN           NaN
#  4  NO NEW WARRANTS CAN BE ISSUED                    NaN           NaN  ,
#  'NASAAC':    Country/Region         Brand LMEsword Code   \
#  0          Canada          ABCQ         ABCQNA
#  1          Canada           ABI          ABINA
#  2          Canada  DESCHAMBAULT         DESCHN
#  3          Canada      WABASH M          WAMNA
#  4           China     YECHIU TC         YETCNA
#
#                                 Producer  Deliverable Shape Warrant Issuance  \
#  0                     Alcoa Corporation             T-bars      WARRANTABLE
#  1          Aluminerie de Becancour Inc.             T-bars      WARRANTABLE
#  2                     Alcoa Corporation             T-bars      WARRANTABLE
#  3                Real Alloy Canada Ltd.  Ingots,Small sows      WARRANTABLE
#  4  Ye Chiu Metal Recycling (China) Ltd.             Ingots      WARRANTABLE
#
#     Last Warrantable Date Special Notes
#  0                    NaN           NaN
#  1                    NaN           NaN
#  2                    NaN           NaN
#  3                    NaN           NaN
#  4                    NaN           NaN  ,
#  'Cobalt':    Country/Region                            Brand LMEsword Code   \
#  0       Australia         MINARA COBALT BRIQUETTES         MINACO
#  1          Brazil      TOCANTINS ALLOY GRADE 99.8%            TOC
#  2          Canada  VALE ELECTROLYTIC COBALT ROUNDS         VALECR
#  3           China                             CASH           CASH
#  4           China                GOLDEN CAMEL 9995         GCAM95
#
#                             Producer  Deliverable Shape  \
#  0          Minara Resources Pty Ltd         Briquettes
#  1            Votorantim Metais S.A.  Cathodes (Broken)
#  2               Vale Canada Limited             Rounds
#  3  Yantai Cash Industrial Co., Ltd.     Cathodes (Cut)
#  4          Jinchuan Group Co., Ltd.     Cathodes (Cut)
#
#                  Warrant Issuance  Last Warrantable Date      Special Notes
#  0                    WARRANTABLE                    NaN                NaN
#  1  NO NEW WARRANTS CAN BE ISSUED                    NaN                NaN
#  2                    WARRANTABLE                    NaN                NaN
#  3                    WARRANTABLE                    NaN  See Notice 17/241
#  4                    WARRANTABLE                    NaN                NaN  }

# %%
#Create a combined dataframe listing the sheet material in a new column
combined_df = pd.concat(
    [df.assign(material=sheet_name) for sheet_name, df in dataframes.items()],
    ignore_index=True
)

# Save the combined dataframe to a CSV file
combined_df.to_csv("combined_data.csv", index=False)

combined_df.head()
# Out:
#    Country/Region  Brand LMEsword Code   \
# 0       Australia    ISA            ISA
# 1       Australia  OLYDA          OLYDA
# 2         Austria    BRX            BRX
# 3         Belgium   OLEN           OLEN
# 4          Brazil    CbM            CBM
#
#                                   Producer    Deliverable Shape  \
# 0                      Mount Isa Mines Ltd  Full plate cathodes
# 1      BHP Olympic Dam Corporation Pty Ltd  Full plate cathodes
# 2  Montanwerke Brixlegg Aktiengesellschaft  Full plate cathodes
# 3                Aurubis Belgium n.v./s.a.  Full plate cathodes
# 4                        Paranapanema S.A.  Full plate cathodes
#
#   Warrant Issuance Last Warrantable Date Special Notes          material  \
# 0      WARRANTABLE                   NaT           NaN  Copper - Grade A
# 1      WARRANTABLE                   NaT           NaN  Copper - Grade A
# 2      WARRANTABLE                   NaT           NaN  Copper - Grade A
# 3      WARRANTABLE                   NaT           NaN  Copper - Grade A
# 4      WARRANTABLE                   NaT           NaN  Copper - Grade A
#
#    Country/Region  ... GRADES   99.97 99.985 99.99 99.97.1 99.985.1 99.99.1  \
# 0             NaN  ...     NaN    NaN    NaN   NaN     NaN      NaN     NaN
# 1             NaN  ...     NaN    NaN    NaN   NaN     NaN      NaN     NaN
# 2             NaN  ...     NaN    NaN    NaN   NaN     NaN      NaN     NaN
# 3             NaN  ...     NaN    NaN    NaN   NaN     NaN      NaN     NaN
# 4             NaN  ...     NaN    NaN    NaN   NaN     NaN      NaN     NaN
#
#   99.994 99.97.2 99.995
# 0    NaN     NaN    NaN
# 1    NaN     NaN    NaN
# 2    NaN     NaN    NaN
# 3    NaN     NaN    NaN
# 4    NaN     NaN    NaN
#
# [5 rows x 22 columns]

# %%
# Select only the desired columns
trimmed_df = combined_df[["Producer","Brand","material"," Country/Region"]]
trimmed_df = trimmed_df.dropna(subset=['Producer'])
# Save the cleaned dataframe to a new CSV file
trimmed_df.to_csv("trimmed_data.csv", index=False)

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re
import numpy as np

# 1) Load the Data
company_list = pd.read_excel('Data (2).xlsx')
company_list['Company'] = company_list['Company'].astype(str).fillna('') # Replace NaN values with empty strings

# 2) Create Parent Company Column: Extract values within parentheses, excluding specific regions
def extract_parent_company(value):
    matches = re.findall(r'\(([^)]+)\)', value)
    for match in matches:
        if match not in ['Australia', 'Uk', 'Europe', 'Holdings', 'the', 'Myanmar', 'U.K.', 'Thailand', 'Switzerland','Sales']:
            return match
    return None

company_list['Parent Company'] = company_list['Company'].apply(extract_parent_company)

# 3) Data Cleaning: Remove phrases "part of" and "formerly" from the "Parent Company" column
company_list['Parent Company'] = company_list['Parent Company'].apply(lambda x: x.replace("part of", "").replace("formerly", "").strip() if pd.notnull(x) else x)

# Function to create the matching column based on a given similarity threshold
def create_matching_column(combined_text, vectorizer, similarity_threshold, column_name):
    tfidf_matrix = vectorizer.fit_transform(combined_text)
    vectors_a = tfidf_matrix[:len(company_list)]
    vectors_b = tfidf_matrix[len(company_list):]
    similarities = cosine_similarity(vectors_b, vectors_a)
    matching_column = [company_list[column_name].iloc[np.argmax(row)] if max(row) > similarity_threshold else None for row in similarities]
    return matching_column

vectorizer = TfidfVectorizer()

# Load data_cleaned DataFrame (can be loaded again or continued from previous operations)
data_cleaned = pd.read_csv('trimmed_data.csv')
data_cleaned['Producer'] = data_cleaned['Producer'].fillna('') # Replace NaN values with empty strings

# 4) Process for Creating the Matching Companies Column 90%
combined_text_companies = pd.concat([company_list['Company'], data_cleaned['Producer']], ignore_index=True)
data_cleaned['Matching Company 90%'] = create_matching_column(combined_text_companies, vectorizer, 0.9, 'Company')

# 5) Process for Creating the Matching Cleaned Parent Companies 50%
combined_text_parent_cleaned = pd.concat([company_list['Parent Company'].fillna(''), data_cleaned['Producer']], ignore_index=True)
data_cleaned['Matching Parent Company Cleaned 50%'] = create_matching_column(combined_text_parent_cleaned, vectorizer, 0.5, 'Parent Company')

# 6) Process for Creating the Matching Companies Column 90%
combined_text_companies = pd.concat([company_list['Company'], data_cleaned['Brand']], ignore_index=True)
data_cleaned['Matching Company_brand 90%'] = create_matching_column(combined_text_companies, vectorizer, 0.9, 'Company')

# 7) Process for Creating the Matching Cleaned Parent Companies 50%
combined_text_parent_cleaned = pd.concat([company_list['Parent Company'].fillna(''), data_cleaned['Brand']], ignore_index=True)
data_cleaned['Matching Parent Company_Brand Cleaned 50%'] = create_matching_column(combined_text_parent_cleaned, vectorizer, 0.5, 'Parent Company')


# Save the updated data_cleaned DataFrame if needed
data_cleaned.to_csv('matched_results.csv', index=False)

# %%
import pandas as pd

# Step 1: Load the matched_results.xlsx file
matched_results = pd.read_csv('matched_results.csv')

# Step 2: Create the "Match" column
matched_columns = ['Matching Company 90%', 'Matching Parent Company Cleaned 50%', 'Matching Company_brand 90%', 'Matching Parent Company_Brand Cleaned 50%']
matched_results['Match'] = matched_results[matched_columns].apply(lambda row: 1 if any(pd.notnull(cell) for cell in row) else 0, axis=1)

# Step 4: Import the values from the columns: Location, Category, and Website based on the matched company

# Create empty columns for Location, Category, and Website in matched_results
matched_results['Location'] = None
matched_results['Category'] = None
matched_results['Website'] = None

# Function to fetch data for matched companies
def fetch_data(row):
    for col in matched_columns:
        matched_company = row[col]
        if pd.notnull(matched_company):
            match_data = company_list[company_list['Company'] == matched_company]
            if not match_data.empty:
                row['Location'] = match_data['Location'].values[0]
                row['Category'] = match_data['Category'].values[0]
                row['Website'] = match_data['Website'].values[0]
                break
    return row

# Apply the function to rows with Match = 1
matched_results = matched_results.apply(lambda row: fetch_data(row) if row['Match'] == 1 else row, axis=1)

matched_results.head()
# Out:
#                                   Producer  Brand          material  \
# 0                      Mount Isa Mines Ltd    ISA  Copper - Grade A
# 1      BHP Olympic Dam Corporation Pty Ltd  OLYDA  Copper - Grade A
# 2  Montanwerke Brixlegg Aktiengesellschaft    BRX  Copper - Grade A
# 3                Aurubis Belgium n.v./s.a.   OLEN  Copper - Grade A
# 4                        Paranapanema S.A.    CbM  Copper - Grade A
#
#    Country/Region Matching Company 90% Matching Parent Company Cleaned 50%  \
# 0       Australia                  NaN                                 NaN
# 1       Australia                  NaN                                 NaN
# 2         Austria                  NaN                                 NaN
# 3         Belgium                  NaN                                 NaN
# 4          Brazil                  NaN                                 NaN
#
#   Matching Company_brand 90% Matching Parent Company_Brand Cleaned 50%  Match  \
# 0                  ISA Group                                 ISA Group      1
# 1                        NaN                                       NaN      0
# 2                        NaN                                       NaN      0
# 3                        NaN                                       NaN      0
# 4                        NaN                                       NaN      0
#
#                    Location                Category                Website
# 0  United States of America  Health Sector: General  http://www.isa.com.co
# 1                      None                    None                   None
# 2                      None                    None                   None
# 3                      None                    None                   None
# 4                      None                    None                   None

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the updated_matched_results.xlsx file
file_path = 'matched_results.csv'
updated_matched_results = pd.read_csv(file_path)

# Sort the DataFrame by company names (Producer) alphabetically
updated_matched_results = updated_matched_results.sort_values(by='Producer')

# Specify the columns for matching
matched_columns = ['Matching Company 90%', 'Matching Parent Company Cleaned 50%', 'Matching Company_brand 90%', 'Matching Parent Company_Brand Cleaned 50%']

# Create a DataFrame with binary values representing the presence of matches in the specified columns
heatmap_data = updated_matched_results[matched_columns].applymap(lambda x: 1 if pd.notnull(x) else 0)

# Plotting the heatmap with company names on the y-axis
plt.figure(figsize=(15, 50), facecolor='white') # Set white background
sns.heatmap(heatmap_data, cmap="YlGnBu", cbar=True, yticklabels=updated_matched_results['Producer'])
plt.title("Heatmap Representation of Matches")
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0, fontsize=8)
plt.tight_layout()

# Save the expanded heatmap with readable y-axis labels as an image file
expanded_heatmap_image_path = 'expanded_heatmap_image.png'
plt.savefig(expanded_heatmap_image_path, dpi=300, facecolor='white')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap

# Load the updated_matched_results.xlsx file
file_path = 'matched_results.csv'
updated_matched_results = pd.read_csv(file_path)

# Sort the DataFrame by company names (Producer) alphabetically
updated_matched_results = updated_matched_results.sort_values(by='Producer')

# Specify the columns for matching
matched_columns = ['Matching Company 90%', 'Matching Parent Company Cleaned 50%', 'Matching Company_brand 90%', 'Matching Parent Company_Brand Cleaned 50%']

# Create a DataFrame with binary values representing the presence of matches in the specified columns
heatmap_data = updated_matched_results[matched_columns].applymap(lambda x: 1 if pd.notnull(x) else 0)

# Create a custom colormap that transitions from navy to yellow
colors = ["navy", "blue", "dodgerblue", "turquoise", "yellowgreen", "yellow"]
custom_colormap = LinearSegmentedColormap.from_list("custom_colormap", colors, N=heatmap_data.shape[1])

# Plotting the heatmap with company names on the y-axis
plt.figure(figsize=(15, 50), facecolor='white')
sns.heatmap(heatmap_data, cmap=custom_colormap, cbar=True, yticklabels=updated_matched_results['Producer'])
plt.title("Heatmap Representation of Matches")
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0, fontsize=8)
plt.tight_layout()

# Save the expanded heatmap with readable y-axis labels as an image file
expanded_heatmap_image_path = 'expanded_heatmap_image.png'
plt.savefig(expanded_heatmap_image_path, dpi=300, facecolor='white')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap

# Mockup data loading for demonstration
# file_path = 'matched_results.csv'
# updated_matched_results = pd.read_csv(file_path)
# Mockup data for demonstration
file_path = 'matched_results.csv'
updated_matched_results = pd.read_csv(file_path)


# Sort the DataFrame by company names (Producer) alphabetically
updated_matched_results = updated_matched_results.sort_values(by='Producer')

# Specify the columns for matching
matched_columns = ['Matching Company 90%', 'Matching Parent Company Cleaned 50%', 'Matching Company_brand 90%', 'Matching Parent Company_Brand Cleaned 50%']

# Create a DataFrame with binary values representing the presence of matches in the specified columns
heatmap_data = updated_matched_results[matched_columns].applymap(lambda x: 1 if pd.notnull(x) else 0)

# Create individual colormaps for each column
colors = [
    ["white", "navy"], 
    ["white", "blue"], 
    ["white", "turquoise"], 
    ["white", "yellow"]
]
colormaps = [LinearSegmentedColormap.from_list(f"colormap_{i}", color, N=2) for i, color in enumerate(colors)]

# Set up the plotting environment
plt.figure(figsize=(15, 100), facecolor='white')

# Iterate over each column and plot individual heatmaps
for i, column in enumerate(matched_columns):
    plt.subplot(1, len(matched_columns), i+1)
    sns.heatmap(heatmap_data[[column]], cmap=colormaps[i], cbar=False, yticklabels=updated_matched_results['Producer'] if i == 0 else False)
    
    plt.xticks([])  # remove x ticks as they are not needed
    plt.xlabel(column, rotation=45)  # rotate x-labels

plt.tight_layout()  # Adjust layout for better appearance

# Save the expanded heatmap with readable y-axis labels as an image file
expanded_heatmap_image_path = "expanded_heatmap_image.png"
plt.savefig(expanded_heatmap_image_path, dpi=300, facecolor='white')

plt.show()

expanded_heatmap_image_path
# Out:
# 'expanded_heatmap_image.png'

# %%
import os
import openai
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Set the OpenAI API key
openai.api_key = ""

# Prompt for the company name
company_name = input("Enter the company name: ")

# Send the prompt to the API
response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {
            "role": "system",
            "content": "Data Engineer creating lists to use in an app later."
        },
        {
            "role": "user",
            "content": f"List all of the subsidiaries of the company {company_name} as a list in python with no other supporting text. Only the list in a usable format with no line breaks."
        }
    ],
    temperature=1,
    max_tokens=256,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

# Extract the list of subsidiaries from the response
subsidiaries = eval(response['choices'][0]['message']['content'])

# Load the trimmed_data.csv
data_cleaned = pd.read_csv('trimmed_data.csv')
data_cleaned['Producer'] = data_cleaned['Producer'].fillna('')

# Create a temporary DataFrame using the retrieved subsidiaries
company_temp_df = pd.DataFrame({
    'Company': subsidiaries,
    'Parent Company': [company_name] * len(subsidiaries)
})

# Initialize the vectorizer
vectorizer = TfidfVectorizer()

# Define the create_matching_column function
def create_matching_column(combined_text, vectorizer, similarity_threshold, column_name):
    tfidf_matrix = vectorizer.fit_transform(combined_text)
    vectors_a = tfidf_matrix[:len(company_temp_df)]
    vectors_b = tfidf_matrix[len(company_temp_df):]
    similarities = cosine_similarity(vectors_b, vectors_a)
    matching_column = [company_temp_df[column_name].iloc[np.argmax(row)] if max(row) > similarity_threshold else None for row in similarities]
    return matching_column

# Run the matching process using the retrieved subsidiaries
combined_text_companies = pd.concat([company_temp_df['Company'], data_cleaned['Producer']], ignore_index=True)
data_cleaned['Matching Company 90%'] = create_matching_column(combined_text_companies, vectorizer, 0.9, 'Company')

# Print the resulting DataFrame
print(data_cleaned)
# Out:
# Enter the company name: Umicore
#                                     Producer      Brand          material  \
# 0                        Mount Isa Mines Ltd        ISA  Copper - Grade A
# 1        BHP Olympic Dam Corporation Pty Ltd      OLYDA  Copper - Grade A
# 2    Montanwerke Brixlegg Aktiengesellschaft        BRX  Copper - Grade A
# 3                  Aurubis Belgium n.v./s.a.       OLEN  Copper - Grade A
# 4                          Paranapanema S.A.        CbM  Copper - Grade A
# ..                                       ...        ...               ...
# 492    CTT - Compagnie de Tifnout Tiranimine       CMBA            Cobalt
# 493                           JSC "Kola GMK"  NORNICKEL            Cobalt
# 494            Kasese Cobalt Company Limited       KCCL            Cobalt
# 495                     Chambishi Metals Plc        CMA            Cobalt
# 496                     Chambishi Metals Plc        CMP            Cobalt
#
#      Country/Region Matching Company 90%
# 0         Australia                 None
# 1         Australia                 None
# 2           Austria                 None
# 3           Belgium                 None
# 4            Brazil                 None
# ..              ...                  ...
# 492         Morocco                 None
# 493          Russia                 None
# 494          Uganda                 None
# 495          Zambia                 None
# 496          Zambia                 None
#
# [497 rows x 5 columns]

# %%
pip install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openai
#   Downloading openai-0.27.8-py3-none-any.whl (73 kB)
# Requirement already satisfied: requests>=2.20 in c:\programdata\anaconda3\lib\site-packages (from openai) (2.27.1)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from openai) (4.64.0)
# Requirement already satisfied: aiohttp in c:\programdata\anaconda3\lib\site-packages (from openai) (3.8.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.20->openai) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.20->openai) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.20->openai) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.20->openai) (1.26.9)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->openai) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->openai) (5.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->openai) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->openai) (1.6.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->openai) (4.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->openai) (21.4.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\programdata\anaconda3\lib\site-packages (from async-timeout<5.0,>=4.0.0a3->aiohttp->openai) (4.1.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm->openai) (0.4.4)
# Installing collected packages: openai
# Successfully installed openai-0.27.8
#   WARNING: The script openai.exe is installed in 'C:\Users\Erler\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import os
import openai
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Set the OpenAI API key
openai.api_key = os.environ.get("OPENAI_API_KEY")

# Prompt for the company name
company_name = input("Enter the company name: ")

# Send the prompt to the API
response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {
            "role": "system",
            "content": "Data Engineer creating lists to use in an app later."
        },
        {
            "role": "user",
            "content": f"List all of the subsidiaries of the company {company_name} as a list in python with no other supporting text. Only the list in a usable format with no line breaks."
        }
    ],
    temperature=1,
    max_tokens=256,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

# Extract the list of subsidiaries from the response
subsidiaries = eval(response['choices'][0]['message']['content'])

# Load the trimmed_data.csv
data_cleaned = pd.read_csv('trimmed_data.csv')
data_cleaned['Producer'] = data_cleaned['Producer'].fillna('')

# Create a temporary DataFrame using the retrieved subsidiaries
company_temp_df = pd.DataFrame({
    'Company': subsidiaries,
    'Parent Company': [company_name] * len(subsidiaries)
})

# Initialize the vectorizer
vectorizer = TfidfVectorizer()

# Define the create_matching_column function
def create_matching_column(combined_text, vectorizer, similarity_threshold, column_name):
    tfidf_matrix = vectorizer.fit_transform(combined_text)
    vectors_a = tfidf_matrix[:len(company_temp_df)]
    vectors_b = tfidf_matrix[len(company_temp_df):]
    similarities = cosine_similarity(vectors_b, vectors_a)
    matching_column = [company_temp_df[column_name].iloc[np.argmax(row)] if max(row) > similarity_threshold else None for row in similarities]
    return matching_column

# Run the matching process using the retrieved subsidiaries
combined_text_companies = pd.concat([company_temp_df['Company'], data_cleaned['Producer']], ignore_index=True)
data_cleaned['Matching Company 75%'] = create_matching_column(combined_text_companies, vectorizer, 0.50, 'Company')
combined_text_brand = pd.concat([company_temp_df['Company'], data_cleaned['Brand']], ignore_index=True)
data_cleaned['Matching Parent Company_Brand Cleaned 50%'] = create_matching_column(combined_text_brand, vectorizer, 0.5, 'Parent Company')


# Filter the DataFrame to display only the rows with matches
matches_exist = data_cleaned[data_cleaned['Matching Company 50%'].notna()]
matches_exist2 = data_cleaned[data_cleaned['Matching Parent Company_Brand Cleaned 50%'].notna()]

# Print the resulting DataFrame with only matches
print(matches_exist)
print(matches_exist2)
# Out:
# Enter the company name: Umicore
#     Producer           Brand material  Country/Region  \
# 108  Umicore   UMICORE 99.97     Lead             NaN
# 109  Umicore  UMICORE 99.985     Lead             NaN
# 110  Umicore   UMICORE 99.99     Lead             NaN
#
#            Matching Company 75% Matching Parent Company_Brand Cleaned 50%
# 108  Umicore Marketing Services                                      None
# 109  Umicore Marketing Services                                      None
# 110  Umicore Marketing Services                                      None
# Empty DataFrame
# Columns: [Producer, Brand, material,  Country/Region, Matching Company 75%, Matching Parent Company_Brand Cleaned 50%]
# Index: []
